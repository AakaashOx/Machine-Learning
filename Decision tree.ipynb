# %%
import pandas as pd
import matplotlib.pyplot as plt

# -----------------------------
# Step 1: Create dataset
# -----------------------------
data = {
    "Age": [22, 25, 28, 30, 35, 40, 45, 50, 23, 27, 32, 38, 42, 48, 55],
    "Income": [3, 4, 6, 8, 10, 12, 7, 6, 2, 5, 9, 11, 4, 5, 9],
    "CreditScore": [650, 680, 720, 750, 780, 800, 700, 690, 640, 710, 760, 790, 660, 680, 740],
    "Experience": [1, 2, 3, 5, 8, 10, 15, 20, 1, 4, 6, 9, 18, 22, 25],
    "BuyCar": [0, 0, 1, 1, 1, 1, 1, 0, 0, 1, 1, 1, 0, 0, 1]
}

dataset = pd.DataFrame(data)

# -----------------------------
# Step 2: Split X and y
# -----------------------------
X = dataset.iloc[:, :-1]
y = dataset.iloc[:, -1]

# -----------------------------
# Step 3: Train-test split
# -----------------------------
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# -----------------------------
# Step 4: Train Decision Tree
# -----------------------------
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion="gini", max_depth=4, random_state=0)
model.fit(X_train, y_train)

# -----------------------------
# Step 5: Evaluate model
# -----------------------------
from sklearn.metrics import accuracy_score
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.75

# %%
# -----------------------------
# Step 6: Visualize Decision Tree
# -----------------------------
from sklearn.tree import plot_tree

plt.figure(figsize=(10, 10))
plot_tree(
    model,
    feature_names=X.columns,
    class_names=["Not Buy", "Buy"],
    filled=True,
    rounded=False
)
plt.title("Decision Tree Classifier – Car Purchase Prediction")
plt.show()

# %%
import joblib

joblib.dump(model, "decision_tree_car_model.pkl")
print("Decision Tree model saved successfully!")
# Out:
# Decision Tree model saved successfully!
