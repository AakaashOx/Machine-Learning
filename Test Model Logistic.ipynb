# %%
import joblib
import numpy as np

model = joblib.load("car_buy_model.pkl")

# User input
age = int(input("Enter Age: "))
income = int(input("Enter Income (Lakhs): "))
credit = int(input("Enter Credit Score: "))
exp = int(input("Enter Years of Experience: "))

new_data = np.array([[age, income, credit, exp]])
prediction = model.predict(new_data)

if prediction[0] == 1:
    print("Prediction: Person WILL buy a car ")
else:
    print("Prediction: Person will NOT buy a car")
# Out:
# Enter Age:  21
# Enter Income (Lakhs):  5
# Enter Credit Score:  897
# Enter Years of Experience:  4
# Prediction: Person WILL buy a car
# C:\Users\money\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
