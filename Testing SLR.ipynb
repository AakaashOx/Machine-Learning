# %%
import joblib
model = joblib.load("marks_model.pkl")

# %%
hours = float(input("Enter hours studied: "))
predicted_marks = model.predict([[hours]])
print("Predicted Marks:", predicted_marks[0])
# Out:
# Enter hours studied:  25.3
# Predicted Marks: 50.24554611890184
# C:\Users\money\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
